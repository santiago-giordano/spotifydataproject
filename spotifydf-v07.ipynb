# %% [markdown]
# # **spotifydataproject**
# ### A spotify data analysis project from a kaggle dataset using:
#
#
#
#
# >* **python**
#
# >* **pandas**
#
# >* **matplotlib**

# %% [markdown]
# ## **1- Importing libraries and dataset:**
# * Pandas
# * Numpy
# * Datetime
# * Matplotlib
# > * Spotify Dataset (https://www.kaggle.com/datasets/naoh1092/spotify-genre-audio-features)

# %%
#Se importan las librerías necesarias
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
#Se carga el archivo excel y se asigna a una variable
spot = pd.read_excel('Spotify Genre Audio features - Kaggle.xlsx')

# %%
#Se chequean las primeras filas del dataframe
spot.head()
# Out:
#   Genre                          Title  \
# 0  rock                   Baba O'Riley
# 1  rock            More Than a Feeling
# 2  rock        (Don't Fear) The Reaper
# 3  rock           Jump - 2015 Remaster
# 4  rock  Stairway to Heaven - Remaster
#
#                                     Album_cover_link            Artist  \
# 0  https://i.scdn.co/image/ab67616d0000b273fe24dc...           The Who
# 1  https://i.scdn.co/image/ab67616d0000b27390ef97...            Boston
# 2  https://i.scdn.co/image/ab67616d0000b2733ac318...  Blue Öyster Cult
# 3  https://i.scdn.co/image/ab67616d0000b273b414c6...         Van Halen
# 4  https://i.scdn.co/image/ab67616d0000b273c8a11e...      Led Zeppelin
#
#    duration_ms  explicit                      id  popularity release_date  \
# 0       300400     False  3qiyyUfYe7CRYLucrPmulD          75   1971-08-14
# 1       285133     False  1QEEqeFIZktqIpPI4jSVSF          78         1976
# 2       308120     False  5QTxFnGygVM4jFQiBovmRo          76         1976
# 3       241599     False  7N3PAbqfTjSEU1edb2tY8j          78   1984-01-04
# 4       482830     False  5CQ30WqJwcep0pYcV4AMNc          79   1971-11-08
#
#   release_date_precision  ...  key  loudness  mode  speechiness  acousticness  \
# 0                    day  ...    5    -8.367     1       0.0352       0.31300
# 1                   year  ...    7    -8.039     1       0.0298       0.00088
# 2                   year  ...    9    -8.550     0       0.0733       0.00290
# 3                    day  ...    0    -6.219     1       0.0317       0.17100
# 4                    day  ...    9   -12.049     0       0.0339       0.58000
#
#    instrumentalness  liveness  valence    tempo  time_signature
# 0          0.185000    0.2870    0.150  117.292               4
# 1          0.002300    0.0504    0.285  108.789               4
# 2          0.000208    0.2970    0.385  141.466               4
# 3          0.000377    0.0702    0.795  129.981               4
# 4          0.003200    0.1160    0.197   82.433               4
#
# [5 rows x 23 columns]

# %% [markdown]
# ## **2- Data Cleansing and Dataframe Formating:**
# * Changing and correcting data types
# * Creating new columns
# * Dropping unnecessary columns
# * Deleting duplicated values
# * Exporting cleaned dataframe into excel file

# %%
#Se chequean los tipos de datos del dataframe
spot.dtypes
# Out:
# Genre                      object
# Title                      object
# Album_cover_link           object
# Artist                     object
# duration_ms                 int64
# explicit                     bool
# id                         object
# popularity                  int64
# release_date               object
# release_date_precision     object
# total_tracks                int64
# danceability              float64
# energy                    float64
# key                         int64
# loudness                  float64
# mode                        int64
# speechiness               float64
# acousticness              float64
# instrumentalness          float64
# liveness                  float64
# valence                   float64
# tempo                     float64
# time_signature              int64
# dtype: object

# %%
#Se modifican los tipos de datos de algunas columnas (a string)
spot[['Genre', 'Title', 'Artist']] = spot[['Genre', 'Title', 'Artist']].astype('string')

# %%
#Se aplica una función lambda para crear la columna 'release_year'
spot['release_year'] = spot['release_date'].apply(lambda x: x[:4])

# %%
#Se podría haber aplicado otro método:
# spot['release_year'] = spot['release_date'].dt.strftime('%Y')

# %%
#Se chequea que la nueva columna se haya creado correctamente
spot['release_year'].head()
# Out:
# 0    1971
# 1    1976
# 2    1976
# 3    1984
# 4    1971
# Name: release_year, dtype: object

# %%
spot.head()
# Out:
#   Genre                          Title  \
# 0  rock                   Baba O'Riley
# 1  rock            More Than a Feeling
# 2  rock        (Don't Fear) The Reaper
# 3  rock           Jump - 2015 Remaster
# 4  rock  Stairway to Heaven - Remaster
#
#                                     Album_cover_link            Artist  \
# 0  https://i.scdn.co/image/ab67616d0000b273fe24dc...           The Who
# 1  https://i.scdn.co/image/ab67616d0000b27390ef97...            Boston
# 2  https://i.scdn.co/image/ab67616d0000b2733ac318...  Blue Öyster Cult
# 3  https://i.scdn.co/image/ab67616d0000b273b414c6...         Van Halen
# 4  https://i.scdn.co/image/ab67616d0000b273c8a11e...      Led Zeppelin
#
#    duration_ms  explicit                      id  popularity release_date  \
# 0       300400     False  3qiyyUfYe7CRYLucrPmulD          75   1971-08-14
# 1       285133     False  1QEEqeFIZktqIpPI4jSVSF          78         1976
# 2       308120     False  5QTxFnGygVM4jFQiBovmRo          76         1976
# 3       241599     False  7N3PAbqfTjSEU1edb2tY8j          78   1984-01-04
# 4       482830     False  5CQ30WqJwcep0pYcV4AMNc          79   1971-11-08
#
#   release_date_precision  ...  loudness  mode  speechiness  acousticness  \
# 0                    day  ...    -8.367     1       0.0352       0.31300
# 1                   year  ...    -8.039     1       0.0298       0.00088
# 2                   year  ...    -8.550     0       0.0733       0.00290
# 3                    day  ...    -6.219     1       0.0317       0.17100
# 4                    day  ...   -12.049     0       0.0339       0.58000
#
#    instrumentalness  liveness  valence    tempo  time_signature  release_year
# 0          0.185000    0.2870    0.150  117.292               4          1971
# 1          0.002300    0.0504    0.285  108.789               4          1976
# 2          0.000208    0.2970    0.385  141.466               4          1976
# 3          0.000377    0.0702    0.795  129.981               4          1984
# 4          0.003200    0.1160    0.197   82.433               4          1971
#
# [5 rows x 24 columns]

# %%
spot.tail()
# Out:
#      Genre             Title  \
# 6912   r&b            Moment
# 6913   r&b  If I Was the One
# 6914   r&b      I Don't Care
# 6915   r&b       Complicated
# 6916   r&b          Innocent
#
#                                        Album_cover_link           Artist  \
# 6912  https://i.scdn.co/image/ab67616d0000b27350aa87...  Victoria MonÃ©t
# 6913  https://i.scdn.co/image/ab67616d0000b2733abb01...        Ruff Endz
# 6914  https://i.scdn.co/image/ab67616d0000b273436ead...      Elle Varner
# 6915  https://i.scdn.co/image/ab67616d0000b273dc377a...      Leela James
# 6916  https://i.scdn.co/image/ab67616d0000b2733cb656...     Justine Skye
#
#       duration_ms  explicit                      id  popularity release_date  \
# 6912       179413      True  6rSUrh8ErKSKfbH0t0IzCM          62   2020-08-07
# 6913       266866     False  1iNO6V1JBTSy9aaiLrOHkZ           1   2000-07-22
# 6914       186466     False  6PxzCYqI60zgJLxxgs1vme          34   2012-08-03
# 6915       244870     False  4qkAApWcCWyhDvQ5d1fsUc          46   2021-07-30
# 6916       173341      True  7A1xtIabfrZ5X3xIa7KqWj          47   2021-06-25
#
#      release_date_precision  ...  loudness  mode  speechiness  acousticness  \
# 6912                    day  ...    -8.889     1       0.0547        0.6370
# 6913                    day  ...    -7.189     1       0.0335        0.3680
# 6914                    day  ...    -4.746     1       0.2110        0.0901
# 6915                    day  ...    -5.287     1       0.1310        0.0629
# 6916                    day  ...    -8.568     0       0.1100        0.1300
#
#       instrumentalness  liveness  valence    tempo  time_signature  \
# 6912          0.005240    0.1220    0.361  130.111               4
# 6913          0.000000    0.0972    0.298  111.832               4
# 6914          0.000000    0.1640    0.578   84.917               4
# 6915          0.000002    0.0616    0.740  139.980               4
# 6916          0.000009    0.1750    0.195   89.347               4
#
#       release_year
# 6912          2020
# 6913          2000
# 6914          2012
# 6915          2021
# 6916          2021
#
# [5 rows x 24 columns]

# %%
#Se modifica el tipo de dato de la columna 'release_date'
spot['release_date'] = pd.to_datetime(spot['release_date'], 
                                      format='%Y/%m/%d')

# %%
#Se modifica el tipo de dato de la nueva columna 'release_year'
spot[['release_year']] = spot[['release_year']].astype('string')

# %%
spot.head()
# Out:
#   Genre                          Title  \
# 0  rock                   Baba O'Riley
# 1  rock            More Than a Feeling
# 2  rock        (Don't Fear) The Reaper
# 3  rock           Jump - 2015 Remaster
# 4  rock  Stairway to Heaven - Remaster
#
#                                     Album_cover_link            Artist  \
# 0  https://i.scdn.co/image/ab67616d0000b273fe24dc...           The Who
# 1  https://i.scdn.co/image/ab67616d0000b27390ef97...            Boston
# 2  https://i.scdn.co/image/ab67616d0000b2733ac318...  Blue Öyster Cult
# 3  https://i.scdn.co/image/ab67616d0000b273b414c6...         Van Halen
# 4  https://i.scdn.co/image/ab67616d0000b273c8a11e...      Led Zeppelin
#
#    duration_ms  explicit                      id  popularity release_date  \
# 0       300400     False  3qiyyUfYe7CRYLucrPmulD          75   1971-08-14
# 1       285133     False  1QEEqeFIZktqIpPI4jSVSF          78   1976-01-01
# 2       308120     False  5QTxFnGygVM4jFQiBovmRo          76   1976-01-01
# 3       241599     False  7N3PAbqfTjSEU1edb2tY8j          78   1984-01-04
# 4       482830     False  5CQ30WqJwcep0pYcV4AMNc          79   1971-11-08
#
#   release_date_precision  ...  loudness  mode  speechiness  acousticness  \
# 0                    day  ...    -8.367     1       0.0352       0.31300
# 1                   year  ...    -8.039     1       0.0298       0.00088
# 2                   year  ...    -8.550     0       0.0733       0.00290
# 3                    day  ...    -6.219     1       0.0317       0.17100
# 4                    day  ...   -12.049     0       0.0339       0.58000
#
#    instrumentalness  liveness  valence    tempo  time_signature  release_year
# 0          0.185000    0.2870    0.150  117.292               4          1971
# 1          0.002300    0.0504    0.285  108.789               4          1976
# 2          0.000208    0.2970    0.385  141.466               4          1976
# 3          0.000377    0.0702    0.795  129.981               4          1984
# 4          0.003200    0.1160    0.197   82.433               4          1971
#
# [5 rows x 24 columns]

# %%
#Se eliminan columnas innecesarias
spot.drop(columns=['Album_cover_link', 'release_date_precision', 'total_tracks', 'id'], 
          inplace=True)

# %%
spot.head()
# Out:
#   Genre                          Title            Artist  duration_ms  \
# 0  rock                   Baba O'Riley           The Who       300400
# 1  rock            More Than a Feeling            Boston       285133
# 2  rock        (Don't Fear) The Reaper  Blue Öyster Cult       308120
# 3  rock           Jump - 2015 Remaster         Van Halen       241599
# 4  rock  Stairway to Heaven - Remaster      Led Zeppelin       482830
#
#    explicit  popularity release_date  danceability  energy  key  loudness  \
# 0     False          75   1971-08-14         0.489   0.724    5    -8.367
# 1     False          78   1976-01-01         0.377   0.681    7    -8.039
# 2     False          76   1976-01-01         0.333   0.927    9    -8.550
# 3     False          78   1984-01-04         0.572   0.835    0    -6.219
# 4     False          79   1971-11-08         0.338   0.340    9   -12.049
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0352       0.31300          0.185000    0.2870    0.150
# 1     1       0.0298       0.00088          0.002300    0.0504    0.285
# 2     0       0.0733       0.00290          0.000208    0.2970    0.385
# 3     1       0.0317       0.17100          0.000377    0.0702    0.795
# 4     0       0.0339       0.58000          0.003200    0.1160    0.197
#
#      tempo  time_signature release_year
# 0  117.292               4         1971
# 1  108.789               4         1976
# 2  141.466               4         1976
# 3  129.981               4         1984
# 4   82.433               4         1971

# %%
#Se crea una función para calcular hace cuántos años fue lanzada la canción
from datetime import date

# %%
def datediff(x):
    today = date.today()
    age = today.year - x.year - ((today.month, today.day) < (x.month, x.day))
    return age

# %%
#Se aplica la función 'datediff' y se guardan los resultados en la nueva columna 'years_since_release'
spot['years_since_release'] = spot['release_date'].apply(datediff)

# %%
spot.head()
# Out:
#   Genre                          Title            Artist  duration_ms  \
# 0  rock                   Baba O'Riley           The Who       300400
# 1  rock            More Than a Feeling            Boston       285133
# 2  rock        (Don't Fear) The Reaper  Blue Öyster Cult       308120
# 3  rock           Jump - 2015 Remaster         Van Halen       241599
# 4  rock  Stairway to Heaven - Remaster      Led Zeppelin       482830
#
#    explicit  popularity release_date  danceability  energy  key  ...  mode  \
# 0     False          75   1971-08-14         0.489   0.724    5  ...     1
# 1     False          78   1976-01-01         0.377   0.681    7  ...     1
# 2     False          76   1976-01-01         0.333   0.927    9  ...     0
# 3     False          78   1984-01-04         0.572   0.835    0  ...     1
# 4     False          79   1971-11-08         0.338   0.340    9  ...     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0352       0.31300          0.185000    0.2870    0.150  117.292
# 1       0.0298       0.00088          0.002300    0.0504    0.285  108.789
# 2       0.0733       0.00290          0.000208    0.2970    0.385  141.466
# 3       0.0317       0.17100          0.000377    0.0702    0.795  129.981
# 4       0.0339       0.58000          0.003200    0.1160    0.197   82.433
#
#    time_signature  release_year years_since_release
# 0               4          1971                  51
# 1               4          1976                  46
# 2               4          1976                  46
# 3               4          1984                  38
# 4               4          1971                  50
#
# [5 rows x 21 columns]

# %%
spot.dtypes
# Out:
# Genre                          string
# Title                          string
# Artist                         string
# duration_ms                     int64
# explicit                         bool
# popularity                      int64
# release_date           datetime64[ns]
# danceability                  float64
# energy                        float64
# key                             int64
# loudness                      float64
# mode                            int64
# speechiness                   float64
# acousticness                  float64
# instrumentalness              float64
# liveness                      float64
# valence                       float64
# tempo                         float64
# time_signature                  int64
# release_year                   string
# years_since_release             int64
# dtype: object

# %%
#Se crea una función para cambiar el contenido de la columna 'explicit' (de boolean a string)
def explicit(x):
    if x==True:
        return 'explicit content'
    else:
        return 'not explicit content'

# %%
#Primero se aplica la función y en un segundo paso se convierte a string (de object a string)
spot['explicit'] = spot['explicit'].apply(explicit)

# %%
spot['explicit'] = spot['explicit'].astype('string')

# %%
spot.tail()
# Out:
#      Genre             Title           Artist  duration_ms  \
# 6912   r&b            Moment  Victoria MonÃ©t       179413
# 6913   r&b  If I Was the One        Ruff Endz       266866
# 6914   r&b      I Don't Care      Elle Varner       186466
# 6915   r&b       Complicated      Leela James       244870
# 6916   r&b          Innocent     Justine Skye       173341
#
#                   explicit  popularity release_date  danceability  energy  \
# 6912      explicit content          62   2020-08-07         0.571   0.431
# 6913  not explicit content           1   2000-07-22         0.627   0.405
# 6914  not explicit content          34   2012-08-03         0.507   0.832
# 6915  not explicit content          46   2021-07-30         0.850   0.700
# 6916      explicit content          47   2021-06-25         0.528   0.349
#
#       key  ...  mode  speechiness  acousticness  instrumentalness  liveness  \
# 6912    1  ...     1       0.0547        0.6370          0.005240    0.1220
# 6913   10  ...     1       0.0335        0.3680          0.000000    0.0972
# 6914    9  ...     1       0.2110        0.0901          0.000000    0.1640
# 6915    8  ...     1       0.1310        0.0629          0.000002    0.0616
# 6916    0  ...     0       0.1100        0.1300          0.000009    0.1750
#
#       valence    tempo  time_signature  release_year years_since_release
# 6912    0.361  130.111               4          2020                   2
# 6913    0.298  111.832               4          2000                  22
# 6914    0.578   84.917               4          2012                  10
# 6915    0.740  139.980               4          2021                   1
# 6916    0.195   89.347               4          2021                   1
#
# [5 rows x 21 columns]

# %%
#Se eliminan los registros duplicados
spot = spot.drop_duplicates(subset='Title')

# %%
#Se exporta el dataset a un nuevo archivo excel
spot.to_excel('spotify_dataset.xlsx', 
              sheet_name='Spotify Dataset')

# %%
spot.dtypes
# Out:
# Genre                          string
# Title                          string
# Artist                         string
# duration_ms                     int64
# explicit                       string
# popularity                      int64
# release_date           datetime64[ns]
# danceability                  float64
# energy                        float64
# key                             int64
# loudness                      float64
# mode                            int64
# speechiness                   float64
# acousticness                  float64
# instrumentalness              float64
# liveness                      float64
# valence                       float64
# tempo                         float64
# time_signature                  int64
# release_year                   string
# years_since_release             int64
# dtype: object

# %% [markdown]
# ## **3- Data analysis and visualization:**
# * Top 10: Most popular songs
# * Average years since release (Top 10 and total)
# * Quantity of songs per genre
# * New dataframe to compare popularity and audio features by genre
# * Bar chart: Level of "loudness" by genre
# * Bar chart: Popularity by genre
# * Pie chart: Percentage of songs by genre
# * Pie chart: Percentage of explicit songs
# * Line chart: Level of "loudness" per decade

# %%
#Top 10 tracks
top_10 = spot.sort_values(by='popularity').tail(10)
top_10.sort_values(by='popularity', 
                   ascending=False)
# Out:
#       Genre                                              Title  \
# 4192    pop                                         Easy On Me
# 4570    pop                                           good 4 u
# 4360    pop                                  Happier Than Ever
# 2079    edm                  Moth To A Flame (with The Weeknd)
# 4628    pop                                    Blinding Lights
# 4433    pop                                            Shivers
# 3070  latin  Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)
# 3447  latin                                           Yonaguni
# 1411    rap              Way 2 Sexy (with Future & Young Thug)
# 3018  latin                                              Volví
#
#                    Artist  duration_ms              explicit  popularity  \
# 4192                Adele       224694  not explicit content         100
# 4570       Olivia Rodrigo       178146      explicit content          94
# 4360        Billie Eilish       298899      explicit content          93
# 2079  Swedish House Mafia       234000  not explicit content          92
# 4628           The Weeknd       200040  not explicit content          92
# 4433           Ed Sheeran       207853  not explicit content          92
# 3070                Tainy       207301  not explicit content          92
# 3447            Bad Bunny       206710      explicit content          92
# 1411                Drake       257604      explicit content          91
# 3018             Aventura       230125      explicit content          91
#
#      release_date  danceability  energy  key  ...  mode  speechiness  \
# 4192   2021-10-14         0.604   0.366    5  ...     1       0.0282
# 4570   2021-05-21         0.563   0.664    9  ...     1       0.1540
# 4360   2021-07-30         0.332   0.225    0  ...     1       0.0348
# 2079   2021-10-22         0.542   0.659    8  ...     1       0.0389
# 4628   2020-03-20         0.514   0.730    1  ...     1       0.0598
# 4433   2021-10-29         0.788   0.859    2  ...     1       0.0856
# 3070   2021-10-05         0.639   0.703    4  ...     0       0.0794
# 3447   2021-06-04         0.644   0.648    1  ...     1       0.1180
# 1411   2021-09-03         0.803   0.597   11  ...     0       0.1410
# 3018   2021-08-03         0.725   0.860    1  ...     1       0.1820
#
#       acousticness  instrumentalness  liveness  valence    tempo  \
# 4192      0.578000          0.000000    0.1330    0.130  141.981
# 4570      0.335000          0.000000    0.0849    0.688  166.928
# 4360      0.767000          0.003490    0.1280    0.297   81.055
# 2079      0.002790          0.000000    0.1050    0.109  120.122
# 4628      0.001460          0.000095    0.0897    0.334  171.005
# 4433      0.281000          0.000000    0.0424    0.822  141.020
# 3070      0.088900          0.000002    0.0865    0.138  169.888
# 3447      0.276000          0.000000    0.1350    0.440  179.951
# 1411      0.000619          0.000005    0.3230    0.331  136.008
# 3018      0.422000          0.000284    0.0674    0.791  175.896
#
#       time_signature  release_year years_since_release
# 4192               4          2021                   0
# 4570               4          2021                   1
# 4360               3          2021                   1
# 2079               4          2021                   0
# 4628               4          2020                   2
# 4433               4          2021                   0
# 3070               4          2021                   0
# 3447               4          2021                   1
# 1411               4          2021                   1
# 3018               4          2021                   1
#
# [10 rows x 21 columns]

# %%
#Se exporta el top 10 a un archivo excel
top_10.to_excel("spottop10.xlsx", 
                sheet_name='Spotify Top 10')

# %%
#Promedio de antigUedad de los tracks del top 10
print(spot.sort_values(by='popularity').tail(10)['years_since_release'].mean(), 
      'años (promedio top 10)')
# Out:
# 0.7 años (promedio top 10)

# %%
#Promedio de antigUedad de la totalidad de los tracks
print(spot['years_since_release'].mean(), 
      'años (promedio total)')
# Out:
# 14.388668847942139 años (promedio total)

# %%
#Cantidad de canciones por género ordenados de manera descendente
spot_genre_count = spot.pivot_table(index='Genre', 
                                    aggfunc='count', 
                                    values='Title').sort_values(by='Title', 
                                                                ascending=False)
spot_genre_count
# Out:
#         Title
# Genre
# rock     1129
# latin    1018
# pop       930
# rap       917
# edm       902
# r&b       484
# hiphop    427

# %% [markdown]
# ## Popularity by genre:

# %%
#Se genera un gráfico de barras de los géneros según su popularidad
# Styling of the figure
fig = plt.figure()
fig.set_figwidth(12)
fig.set_figheight(5)
fig.patch.set_facecolor('white')
plt.bar(spot_genre_afeat['Genre'], 
        spot_genre_afeat['popularity'].sort_values(ascending=True), 
        color=['b','g','r','c','m','y','k'])
plt.title(f'Popularity by genre')
plt.xlabel("Genre") 
plt.ylabel("Popularity") 
# Styling of the plot
plt.grid(color = 'white', linewidth = 0.5)
plt.locator_params(axis='y', nbins=6)
# Styling of the axes
ax = plt.gca()
ax.set_facecolor('#e6ecf7')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.tick_params(axis=u'both', which=u'both',length=0)
plt.savefig('SpotifyDF - Popularity by genre.png', transparent=False)
plt.show()

# %% [markdown]
# ## Percentage of songs by genre:

# %%
#Se convierte el index en columna
spot_genre_count.reset_index(inplace=True)

# %%
#Se genera un gráfico de torta mostrando el porcentaje de canciones por género
fig = plt.figure()
fig.set_figwidth(8)
fig.set_figheight(5)
fig.patch.set_facecolor('white')
explode_pie1 = (0.1, 0, 0, 0, 0, 0 , 0)
plt.pie(spot_genre_count['Title'], 
        labels=spot_genre_count['Genre'], 
        explode=explode_pie1,
        autopct='%1.1f%%',
        shadow=True, 
        startangle=90,
        counterclock=False,
        textprops=dict(color="k"))
plt.title('Percentage of songs by genre')
plt.legend(spot_genre_count['Genre'], 
           loc='center left', 
           bbox_to_anchor=(1.1, 0.5), 
           title='Genres')
plt.savefig('SpotifyDF - Percentage of songs by genre.png', facecolor=fig.get_facecolor(), transparent=False)
plt.show()

# %% [markdown]
# ## Percentage of explicit songs:

# %%
#Se crea una función para poder contar la cantidad de canciones con contenido explícito y sin contenido explícito
def explicit(x):
  if x=='explicit content':
    return 'explicit songs'
  else:
    return 'not explicit songs'

spot_explicit = spot['explicit'].apply(explicit)
spot_explicit
# Out:
# 0       not explicit songs
# 1       not explicit songs
# 2       not explicit songs
# 3       not explicit songs
# 4       not explicit songs
#                ...
# 6908        explicit songs
# 6909    not explicit songs
# 6910    not explicit songs
# 6913    not explicit songs
# 6916        explicit songs
# Name: explicit, Length: 5807, dtype: object

# %%
spot_explicit = spot_explicit.to_frame()
spot_explicit
# Out:
#                 explicit
# 0     not explicit songs
# 1     not explicit songs
# 2     not explicit songs
# 3     not explicit songs
# 4     not explicit songs
# ...                  ...
# 6908      explicit songs
# 6909  not explicit songs
# 6910  not explicit songs
# 6913  not explicit songs
# 6916      explicit songs
#
# [5807 rows x 1 columns]

# %%
spot_explicit.reset_index(inplace=True)
spot_expl_count = spot_explicit.groupby('explicit').count()
spot_expl_count.reset_index(inplace=True)
spot_expl_count
# Out:
#              explicit  index
# 0      explicit songs   1591
# 1  not explicit songs   4216

# %%
fig = plt.figure()
fig.set_figwidth(8)
fig.set_figheight(5)
fig.patch.set_facecolor('white')
explode_pie2 = (0.1, 0)
plt.pie(spot_expl_count['index'], 
        labels=spot_expl_count['explicit'], 
        autopct='%1.1f%%',
        explode=explode_pie2,
        shadow=True, 
        startangle=90,
        counterclock=False,
        textprops=dict(color="k"))
plt.title('Percentage of explicit songs')
plt.legend(spot_expl_count['explicit'], 
           loc='center left',
           bbox_to_anchor=(1, 0.5), 
           title='Content')
plt.savefig('SpotifyDF - Percentage of explicit songs.png', facecolor=fig.get_facecolor(), transparent=False)
plt.show()

# %% [markdown]
# ## >Choose which audio feature to analyze:

# %%
AFEAT = 'acousticness'

# %%
# Primero se crea una tabla para comparar los valores de popularidad y audio features por género

# %%
#Se crea una variable donde se agrupan los registros por género y se suman los valores de cada género
spot_genre = spot.groupby(['Genre']).sum()

# %%
#Se seleccionan algunos de los valores que nos interesa observar
spot_genre_afeat = spot_genre[['popularity', 'danceability', 'speechiness', 'acousticness', 'liveness', 'loudness']]
spot_genre_afeat.sort_values(by='popularity', 
                             ascending=False)
# Out:
#         popularity  danceability  speechiness  acousticness  liveness  \
# Genre
# rock         71846       579.392      61.0500    159.997008  213.9158
# pop          63527       600.544      71.2488    248.572381  147.7778
# latin        58887       719.569      81.1028    277.403614  177.5561
# rap          57630       693.520     179.4326    120.539137  180.7861
# edm          49799       565.745      71.7707     65.036649  180.1764
# r&b          25079       324.619      45.1794    110.860179   75.2299
# hiphop       20554       315.466      96.8319     66.678686   91.3822
#
#         loudness
# Genre
# rock   -8814.625
# pop    -6029.232
# latin  -6295.261
# rap    -6310.958
# edm    -4495.150
# r&b    -3703.748
# hiphop -3403.182

# %%
#Se extraen los valores numéricos absolutos (columna "loudness" tiene valores negativos)
spot_genre_afeat = spot_genre_afeat.abs()
spot_genre_afeat
# Out:
#         popularity  danceability  speechiness  acousticness  liveness  \
# Genre
# edm          49799       565.745      71.7707     65.036649  180.1764
# hiphop       20554       315.466      96.8319     66.678686   91.3822
# latin        58887       719.569      81.1028    277.403614  177.5561
# pop          63527       600.544      71.2488    248.572381  147.7778
# r&b          25079       324.619      45.1794    110.860179   75.2299
# rap          57630       693.520     179.4326    120.539137  180.7861
# rock         71846       579.392      61.0500    159.997008  213.9158
#
#         loudness
# Genre
# edm     4495.150
# hiphop  3403.182
# latin   6295.261
# pop     6029.232
# r&b     3703.748
# rap     6310.958
# rock    8814.625

# %%
#Se exporta la tabla generada a un archivo excel
spot_genre_afeat.to_excel("spot_genre_afeat.xlsx", 
                          sheet_name='Spotify Audio Features by Genre')

# %%
#Se convierte el index en columna y se ordenan los valores por popularidad
spot_genre_afeat.reset_index(inplace=True)
spot_genre_afeat.sort_values('popularity')
# Out:
#     Genre  popularity  danceability  speechiness  acousticness  liveness  \
# 1  hiphop       20554       315.466      96.8319     66.678686   91.3822
# 4     r&b       25079       324.619      45.1794    110.860179   75.2299
# 0     edm       49799       565.745      71.7707     65.036649  180.1764
# 5     rap       57630       693.520     179.4326    120.539137  180.7861
# 2   latin       58887       719.569      81.1028    277.403614  177.5561
# 3     pop       63527       600.544      71.2488    248.572381  147.7778
# 6    rock       71846       579.392      61.0500    159.997008  213.9158
#
#    loudness
# 1  3403.182
# 4  3703.748
# 0  4495.150
# 5  6310.958
# 2  6295.261
# 3  6029.232
# 6  8814.625

# %% [markdown]
# ## Audio feature by genre:

# %%
#Se genera un gráfico de barras con los valores de 'loudness' según género
# Styling of the figure
fig = plt.figure()
fig.set_figwidth(12)
fig.set_figheight(5)
fig.patch.set_facecolor('white')
plt.bar(spot_genre_afeat['Genre'], 
        spot_genre_afeat[AFEAT].sort_values(ascending=True), 
        color=['b','g','r','c','m','y','k'])
plt.title(f'Level of {AFEAT} by genre')
plt.xlabel("Genre") 
plt.ylabel(AFEAT) 
# Styling of the plot
plt.grid(color = 'white', linewidth = 0.5)
plt.locator_params(axis='y', nbins=6)
# Styling of the axes
ax = plt.gca()
ax.set_facecolor('#e6ecf7')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.tick_params(axis=u'both', which=u'both',length=0)
plt.savefig(f'SpotifyDF - Level of {AFEAT} by genre.png', transparent=False)
plt.show()

# %% [markdown]
# ## Audio features per decade:

# %%
# Se crea un dataframe nuevo para analizar por década
spot[['Title', 'release_year']].sort_values('release_year', ascending=True).head()
# Out:
#                                         Title release_year
# 310                           Johnny B. Goode         1959
# 1126                      Blowin' in the Wind         1963
# 879                        You Never Can Tell         1964
# 110                   House Of The Rising Sun         1964
# 889   The Sound of Silence - Acoustic Version         1964

# %%
spot2 = spot[['Title', 'Genre', AFEAT,'release_year']]
spot2.dtypes
# Out:
# Title            string
# Genre            string
# acousticness    float64
# release_year     string
# dtype: object

# %%
spot2 = spot2.sort_values('release_year', ascending=True)

# %%
spot2['release_year'] = spot2['release_year'].astype(int)

# %%
spot2.dtypes
# Out:
# Title            string
# Genre            string
# acousticness    float64
# release_year      int32
# dtype: object

# %%
spot_afeat_dec = spot2[AFEAT].groupby((spot2['release_year']//10)*10).mean()
spot_afeat_dec = spot_afeat_dec.to_frame()

# %%
spot_afeat_dec.reset_index(inplace=True)
spot_afeat_dec = spot_afeat_dec.abs()
spot_afeat_dec
# Out:
#    release_year  acousticness
# 0          1950      0.741000
# 1          1960      0.343143
# 2          1970      0.248881
# 3          1980      0.133977
# 4          1990      0.157641
# 5          2000      0.179034
# 6          2010      0.187839
# 7          2020      0.175206

# %%
spot_afeat_dec.rename(columns={'release_year': 'decade'}, inplace=True)
spot_afeat_dec
# Out:
#    decade  acousticness
# 0    1950      0.741000
# 1    1960      0.343143
# 2    1970      0.248881
# 3    1980      0.133977
# 4    1990      0.157641
# 5    2000      0.179034
# 6    2010      0.187839
# 7    2020      0.175206

# %%
#En caso de querer extraer los últimos dos números del año
#spot_loud_dec['release_year'] = spot_loud_dec['release_year'].astype(str)
#spot_loud_dec['decade'] = spot_loud_dec['release_year'].apply(lambda x: x[2:4])
#spot_loud_dec"""

# %%
#Se genera un gráfico de línea con los valores de 'loudness' por década
# Styling of the figure
fig = plt.figure()
fig.set_figwidth(12)
fig.set_figheight(5)
fig.patch.set_facecolor('white')
plt.plot(spot_afeat_dec['decade'], spot_afeat_dec[AFEAT].sort_values(ascending=True), color='#004cff')
plt.title(f'Level of {AFEAT} per decade')
plt.xlabel("Decade") 
plt.ylabel(AFEAT) 
# Styling of the plot
plt.grid(color = 'white', linewidth = 1)
plt.locator_params(axis='y', nbins=6)
# Styling of the axes
ax = plt.gca()
ax.set_facecolor('#e6ecf7')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.tick_params(axis=u'both', which=u'both',length=0)
plt.savefig(f'SpotifyDF - Level of {AFEAT} per decade.png', transparent=False)
plt.show()

# %% [markdown]
# ### Comparing charts side by side:

# %%
# Se comparan gráficos lado a lado para evaluar correlación

# Creating the figure and axes
fig, (ax1,ax2) = plt.subplots(nrows=1,ncols=2, figsize=(20,8))
fig.patch.set_facecolor('white')

# Labels ans titles
ax1.set_title('Popularity by genre')
ax1.set_xlabel('Genre')
ax1.set_ylabel('popularity')

ax2.set_title(f'Level of {AFEAT} by genre')
ax2.set_xlabel('Genre')
ax2.set_ylabel(AFEAT)

# Plot 1
ax1.bar(spot_genre_afeat['Genre'], 
        spot_genre_afeat['popularity'].sort_values(ascending=True), 
        color=['b','g','r','c','m','y','k'])

# Plot 2
ax2.bar(spot_genre_afeat['Genre'], 
        spot_genre_afeat[AFEAT].sort_values(ascending=True), 
        color=['b','g','r','c','m','y','k'])
plt.savefig(f'SpotifyDF - Comparing popularity and {AFEAT} charts by genre.png', transparent=False)
plt.show()
